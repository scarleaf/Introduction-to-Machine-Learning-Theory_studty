# %% [markdown]
# # 1. 패키지 불러오기

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from pandas import Series, DataFrame
from numpy.random import normal

# %% [markdown]
# # 2. 파라미터 설정

# %%
N=10                # 샘플의 개수
M=[0,3,6,9]  # 다항식의 차수

# %% [markdown]
# # 3. 함수 정의

# %%
# 데이터셋준비 {x_n,y_n} (n=1...N)
def create_dataset(num):
    dataset = DataFrame(columns=['x','y'])
    for i in range(num):
        x = float(i)/float(num-1)
        y = np.sin(2*np.pi*x) + normal(scale=0.3)
        dataset = dataset.append(Series([x,y], index=['x','y']),
                                 ignore_index=True)
    return dataset

# 평균제곱근편차(mean-square error) 계산
def rms_error(dataset, f):
    err = 0.0
    for index, line in dataset.iterrows():
        x, y = line.x, line.y
        err += 0.5 * (y - f(x))**2
    return np.sqrt(2 * err / len(dataset))

# square 최소화하는 방법으로 해를 구함.
def resolve(dataset, m):
    t = dataset.y
    phi = DataFrame()
    for i in range(0,m+1):
        p = dataset.x**i
        p.name="x**%d" % i
        phi = pd.concat([phi,p], axis=1)
    tmp = np.linalg.inv(np.dot(phi.T, phi))
    ws = np.dot(np.dot(tmp, phi.T), t)

    def f(x):
        y = 0
        for i, w in enumerate(ws):
            y += w * (x ** i)
        return y

    return (f, ws)

# %% [markdown]
# # 4. Main

# %%
if __name__ == '__main__':
    train_set = create_dataset(N)
    test_set = create_dataset(N)
    df_ws = DataFrame()

    # 다항식의 근사치 계산
    fig = plt.figure()
    for c, m in enumerate(M):
        f, ws = resolve(train_set, m)
        df_ws = df_ws.append(Series(ws,name="M=%d" % m))

        subplot = fig.add_subplot(2,2,c+1)
        subplot.set_xlim(-0.05,1.05)
        subplot.set_ylim(-1.5,1.5)
        subplot.set_title("M=%d" % m)

        # Training Set Plot으로 그리기
        subplot.scatter(train_set.x, train_set.y,
                        marker='o', color='blue', label=None)

        # True Curve 보여주기, 녹색점선
        linex = np.linspace(0,1,101)
        liney = np.sin(2*np.pi*linex)
        subplot.plot(linex, liney, color='green', linestyle='--')

        # 각 다항식에 대한 Approximate Curve 표시, 빨강실선
        linex = np.linspace(0,1,101)
        liney = f(linex)
        label = "E(RMS)=%.2f" % rms_error(train_set, f)
        subplot.plot(linex, liney, color='red', label=label)
        subplot.legend(loc=1)
        fig.tight_layout()

# %%
# coefficients Table 출력
    print("Table of the coefficients")
    print(df_ws.transpose())
    plt.show()
# Out:
# Table of the coefficients
#          M=0       M=1        M=3           M=9          M=12
# 0  -0.040757  0.643309   0.001299      0.309022  3.616003e-01
# 1        NaN -1.368132  10.133997      2.286331  3.067102e+00
# 2        NaN       NaN -32.492914   -185.399758 -6.912808e+02
# 3        NaN       NaN  22.805954   2789.932361  1.871821e+04
# 4        NaN       NaN        NaN -15972.983296 -2.232692e+05
# 5        NaN       NaN        NaN  46571.736683  1.506012e+06
# 6        NaN       NaN        NaN -76958.025729 -6.298449e+06
# 7        NaN       NaN        NaN  73193.110704  1.704349e+07
# 8        NaN       NaN        NaN -37408.206972 -3.032426e+07
# 9        NaN       NaN        NaN   7967.632547  3.520725e+07
# 10       NaN       NaN        NaN           NaN -2.566077e+07
# 11       NaN       NaN        NaN           NaN  1.065285e+07
# 12       NaN       NaN        NaN           NaN -1.920892e+06

# %%
 # Training Set과 Test Set에 대한 RMS Error 값 그래프 그리기
    df = DataFrame(columns=['Training set','Test set'])
    for m in range(0,N):   # 샘플 수 만큼 반복문
        f, ws = resolve(train_set, m)
        train_error = rms_error(train_set, f)
        test_error = rms_error(test_set, f)
        df = df.append(
                Series([train_error, test_error],
                    index=['Training set','Test set']),
                ignore_index=True)
    df.plot(title='RMS Error', style=['-','--'], grid=True, ylim=(0,0.9))
    plt.show()
